# %%
import matplotlib.pyplot as plt
import json

# %%
with open('myKV_cuckoo.json', 'r') as f:
    d = json.load(f)

# %%
tableNumList1S = ['myKV_cuckoo', 'myKV_simple', 'myKV_hopscotch', 'ycsbc']
tableNumList2S = ['myKV2S_cuckoo', 'myKV2S_simple', 'myKV2S_hopscotch', 'ycsbc']

# %%
def draw(fnameList, wl):
    for fname in fnameList:
        _fname = fname + '.json'
        f = open(_fname, 'r')
        d = json.load(f)
        f.close()
        dx = d[wl]['tnum']
        dy = d[wl]['tput']
        plt.plot(dx[:10], dy[:10])
    plt.legend(['cuckoo', 'simple', 'hopscotch', 'redis'])
    plt.xlabel("Num Threads")
    plt.ylabel("Throughput (Kops)")
    plt.savefig('2S_{}.pdf'.format(wl), bbox='tight')

# %%
draw(tableNumList1S, 'E')
# Out:
# <ipython-input-40-d1104196c82a>:13: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "bbox" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig('1S_{}.pdf'.format(wl), bbox='tight')

# %%
draw(tableNumList2S, 'E')
# Out:
# <ipython-input-47-5a90a6498a89>:13: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "bbox" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig('2S_{}.pdf'.format(wl), bbox='tight')
